# %% [markdown]
# # Intro and Data Exploration

# %% [markdown]
# Goal: Load and explore a medical tabular dataset and create a train test split.

# %%
from workshop_utils import load_dataset, basic_train_test_split

# TODO 0.1: load the blood pressure dataset
# Tutorial: https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html
df = load_dataset("bp")

# TODO 0.2: inspect the dataset
# Tutorial: https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html
display(df.head())

# TODO 0.3: create train and test sets
# Tutorial: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
X_train, X_test, y_train, y_test = basic_train_test_split(df, target="sbp")

print(X_train.shape, X_test.shape)
