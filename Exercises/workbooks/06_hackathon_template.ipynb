# %% [markdown]
# # Hackathon Template

# %% [markdown]
# Goal: Apply the full supervised ML pipeline to a new clinical risk dataset.

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score



def load_dataset(name: str) -> pd.DataFrame:
    base_url = (
        "https://raw.githubusercontent.com/"
        "Jesse-Islam/QLS-MiCM_Introduction_to_supervised_machine_learning/main/Exercises/data/"
    )
    url = f"{base_url}{name}.csv"
    
    try:
        return pd.read_csv(url)
    except Exception as e:
        raise FileNotFoundError(f"Could not load dataset '{name}' from {url}") from e



def basic_train_test_split(df: pd.DataFrame, target: str, test_size: float = 0.2, random_state: int = 42):
    X = df.drop(columns=[target])
    y = df[target]
    return train_test_split(X, y, test_size=test_size, random_state=random_state)


def build_preprocessor(num_features, cat_features):
    numeric_transformer = StandardScaler()
    categorical_transformer = OneHotEncoder(handle_unknown="ignore")
    preprocessor = ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, num_features),
            ("cat", categorical_transformer, cat_features),
        ]
    )
    return preprocessor

# %%
df = load_dataset("clinical_risk")
X_train, X_test, y_train, y_test = basic_train_test_split(df, target="diabetes")

num_features = ["age", "bmi", "glucose", "bp"]
cat_features = ["sex"]
preprocessor = build_preprocessor(num_features, cat_features)

model = LogisticRegression(max_iter=1000)

pipe = Pipeline(steps=[("preprocess", preprocessor), ("model", model)])
pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))

if hasattr(pipe["model"], "predict_proba"):
    y_prob = pipe.predict_proba(X_test)[:, 1]
    print("ROC AUC:", roc_auc_score(y_test, y_prob))

# %% [markdown]
# ### Your job now
#
# The code above builds a **baseline** with logistic regression.
#
# Now try to improve performance by changing **only the model step** in the pipeline.
# Because preprocessing is already inside the pipeline, you can drop in any scikit-learn tool, or classifier:
#
# ```python
# from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
# from sklearn.neural_network import MLPClassifier
# from sklearn.svm import SVC

# %% [markdown]
# ### Team Notes — what we tried & why
#
# Use this cell like a scratchpad while you experiment.
# Keep it short — just bullet points so you can explain your thought process later.
#
# **Baseline score:**
# - Model: Logistic Regression
# - ROC AUC: ___
#
# **What we changed (and why):**
# - Tried __________________ because ______________________
# - Tried __________________ because ______________________
# - Changed hyperparameter __________________ to __________________ (reason)
#
# **Best score so far:**
# - Model: __________________
# - ROC AUC: _______
#
# **Intuition / takeaway:**
# - What seemed to help?
# - What didn’t?
# - What’s your hypothesis about *why*?
